# %%
import pandas as pd

# %%
df_unclean=pd.read_csv("I:/Masters/SPRING 18/SPATIAL AND TEMPORAL/spatial/project/final/maindata.csv")
df_unclean.dropna()
# Out:
#                ID Case Number                    Date  \
# 0        10000092    HY189866  03/18/2015 07:44:00 PM
# 1        10000094    HY190059  03/18/2015 11:00:00 PM
# 2        10000095    HY190052  03/18/2015 10:45:00 PM
# 3        10000096    HY190054  03/18/2015 10:30:00 PM
# 4        10000097    HY189976  03/18/2015 09:00:00 PM
# 5        10000098    HY190032  03/18/2015 10:00:00 PM
# 6        10000099    HY190047  03/18/2015 11:00:00 PM
# 7        10000100    HY189988  03/18/2015 09:35:00 PM
# 8        10000101    HY190020  03/18/2015 10:09:00 PM
# 9        10000104    HY189964  03/18/2015 09:25:00 PM
# 10       10000105    HY189984  03/18/2015 09:30:00 PM
# 11       10000108    HY189719  03/15/2015 04:10:00 PM
# 12       10000109    HY189966  03/18/2015 09:14:00 PM
# 13       10000110    HY190056  03/18/2015 10:50:00 PM
# 14       10000111    HY190019  03/18/2015 10:31:00 PM
# 15       10000112    HY189725  03/18/2015 12:55:00 PM
# ...

# %%
df = df_unclean[(df_unclean['Year'] >= 2011) & (df_unclean['Year'] <= 2017)]

# %%
df[:10]
# Out:
#          ID Case Number                    Date                   Block  IUCR  \
# 0  10000092    HY189866  03/18/2015 07:44:00 PM         047XX W OHIO ST  041A
# 1  10000094    HY190059  03/18/2015 11:00:00 PM  066XX S MARSHFIELD AVE  4625
# 2  10000095    HY190052  03/18/2015 10:45:00 PM   044XX S LAKE PARK AVE  0486
# 3  10000096    HY190054  03/18/2015 10:30:00 PM    051XX S MICHIGAN AVE  0460
# 4  10000097    HY189976  03/18/2015 09:00:00 PM        047XX W ADAMS ST  031A
# 5  10000098    HY190032  03/18/2015 10:00:00 PM     049XX S DREXEL BLVD  0460
# 6  10000099    HY190047  03/18/2015 11:00:00 PM       070XX S MORGAN ST  0486
# 7  10000100    HY189988  03/18/2015 09:35:00 PM     042XX S PRAIRIE AVE  0486
# 8  10000101    HY190020  03/18/2015 10:09:00 PM     036XX S WOLCOTT AVE  1811
# 9  10000104    HY189964  03/18/2015 09:25:00 PM     097XX S PRAIRIE AVE  0460
#
#     Primary Type                   Description     Location Description  \
# ...

# %%
df.to_csv("I:/Masters/SPRING 18/SPATIAL AND TEMPORAL/spatial/project/final/data2011on.csv")
